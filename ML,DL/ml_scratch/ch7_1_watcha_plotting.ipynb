# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_data = np.array([8759, 10132,12078, 16430])
y_data = np.array([487, 612,866,1030])

plt.scatter(x_data,y_data, color = 'b', marker="^")
plt.show()

# %%
weight_0 = np.random.sample(5)
weight_1 = np.random.sample(5)

weight_0, weight_1
# Out:
# (array([0.54056819, 0.25922216, 0.65527081, 0.12613597, 0.91495831]),
#  array([0.35738245, 0.31949078, 0.44165854, 0.8257917 , 0.53734268]))

# %%
y_hat_list = []
for w0, w1 in zip(weight_0,weight_1):
    y_hat_list.append(w0 + w1*x_data)
y_hat_list
# Out:
# [array([3130.85344911, 3621.53955318, 4317.00580118, 5872.33422426]),
#  array([2798.6789792 , 3237.3398225 , 3859.06888371, 5249.49276573]),
#  array([3869.14242885, 4475.53960524, 5335.00712545, 7257.10509459]),
#  array([ 7233.2356089 ,  8367.04760871,  9974.03825083, 13567.88371564]),
#  array([4707.49951062, 5445.27101312, 6490.93987244, 8829.45522484])]

# %%
plt.scatter(x_data,y_data, color = 'r', marker="s")
for y_hat in y_hat_list:
    plt.plot(x_data, y_hat)
    
plt.show() #들여쓰기시 포문 같이 돌아감

# %%
y_hat[0] - y_data
# Out:
# array([1806.79560776, 1681.79560776, 1427.79560776, 1263.79560776])

# %%
sum( (y_hat - y_data) ** 2 )
# Out:
# 23410380.446117643
